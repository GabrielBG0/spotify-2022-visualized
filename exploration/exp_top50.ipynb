# %%
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_columns', None)
sns.set_style("darkgrid")
sns.set_palette("colorblind")
sns.set_context("poster", font_scale=1, rc={
                "grid.linewidth": 5, "axes.linewidth": 5})

# %%
df = pd.read_csv('top_songs_2022.csv')
df
# Out:
#     position                                               name  popularity  \
# 0          1                                          As It Was          89
# 1          2                                         Heat Waves          83
# 2          3                          STAY (with Justin Bieber)          84
# 3          4                                    Me Porto Bonito          89
# 4          5                                   Tití Me Preguntó          89
# 5          6                            Cold Heart - PNAU Remix          82
# 6          7  Enemy (with JID) - from the series Arcane Leag...          81
# 7          8              Quevedo: Bzrp Music Sessions, Vol. 52          91
# 8          9                                      Ojitos Lindos          88
# 9         10  Running Up That Hill (A Deal With God) - 2018 ...          76
# 10        11                  INDUSTRY BABY (feat. Jack Harlow)          80
# 11        12                                            abcdefu          81
# 12        13                                             Efecto          88
# 13        14                                              Ghost          82
# 14        15                                      Glimpse of Us          84
# 15        16                                        Moscow Mule          85
# 16        17                                            Shivers          83
# 17        18                                         Easy On Me          81
# 18        19                                MIDDLE OF THE NIGHT          83
# 19        20                                              Woman          83
# 20        21                                    Sweater Weather          88
# 21        22                                       Desesperados          79
# 22        23                                       Another Love          89
# 23        24                                           PROVENZA          85
# 24        25                         Bam Bam (feat. Ed Sheeran)          79
# 25        26                                        First Class          80
# 26        27                                    Blinding Lights          87
# 27        28                                             MAMIII          77
# 28        29                                  Where Are You Now          83
# 29        30                                         Bad Habits          83
# 30        31                                              Pepas          80
# 31        32                                           good 4 u          82
# 32        33                                         Dandelions          86
# 33        34                                    About Damn Time          81
# 34        35                                  THATS WHAT I WANT          80
# 35        36                                    I Ain't Worried          90
# 36        37                                        My Universe          77
# 37        38                                         La Bachata          92
# 38        39                              Una Noche en Medellín          82
# 39        40                                      I Love You So          84
# 40        41                                           Infinity          80
# 41        42                                              Party          82
# 42        43                                   Watermelon Sugar          85
# 43        44                                          The Motto          81
# 44        45                                            traitor          82
# 45        46                                 Late Night Talking          86
# 46        47                                  Until I Found You          83
# 47        48  Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)          80
# 48        49                                           Yonaguni          83
# 49        50                                              Tarot          82
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.52    0.73    6     -5.34     0         0.06          0.34
# 1           0.76    0.53   11     -6.90     1         0.09          0.44
# 2           0.59    0.76    1     -5.48     1         0.05          0.04
# 3           0.91    0.71    1     -5.11     0         0.08          0.09
# 4           0.65    0.71    5     -5.20     0         0.25          0.10
# 5           0.80    0.80    1     -6.31     1         0.03          0.03
# 6           0.73    0.78   11     -4.42     0         0.27          0.24
# 7           0.62    0.78    2     -5.55     1         0.04          0.01
# 8           0.65    0.69    3     -5.75     0         0.04          0.08
# 9           0.62    0.53   10    -11.90     0         0.06          0.66
# 10          0.74    0.70    3     -7.41     0         0.06          0.02
# 11          0.69    0.54    4     -5.69     1         0.05          0.30
# 12          0.80    0.47    7     -8.80     0         0.05          0.14
# 13          0.60    0.74    2     -5.57     1         0.05          0.18
# 14          0.44    0.32    8     -9.26     1         0.05          0.89
# 15          0.80    0.67    5     -5.45     0         0.03          0.29
# 16          0.79    0.86    2     -2.72     1         0.09          0.28
# 17          0.60    0.37    5     -7.52     1         0.03          0.58
# 18          0.41    0.61    4     -8.27     0         0.05          0.02
# 19          0.82    0.76    5     -4.17     0         0.09          0.09
# 20          0.61    0.81   10     -2.81     1         0.03          0.05
# 21          0.87    0.69    1     -3.35     0         0.08          0.36
# 22          0.45    0.54    4     -8.53     0         0.04          0.69
# 23          0.87    0.52    1     -8.01     1         0.05          0.66
# 24          0.76    0.70    8     -6.38     1         0.04          0.18
# 25          0.90    0.58    5     -5.90     0         0.11          0.11
# 26          0.51    0.73    1     -5.93     1         0.06          0.00
# 27          0.84    0.70    4     -3.56     0         0.08          0.09
# 28          0.67    0.64    6     -8.12     0         0.10          0.52
# 29          0.81    0.89   11     -3.75     0         0.03          0.05
# 30          0.76    0.77    7     -3.96     1         0.03          0.01
# 31          0.56    0.66    9     -5.04     1         0.15          0.34
# 32          0.61    0.69    1     -2.96     1         0.03          0.02
# 33          0.84    0.74   10     -6.30     0         0.07          0.10
# 34          0.74    0.85    1     -4.51     0         0.22          0.01
# 35          0.70    0.80    0     -5.93     1         0.05          0.08
# 36          0.57    0.71    1     -6.27     0         0.04          0.01
# 37          0.83    0.68    7     -5.33     0         0.04          0.58
# 38          0.87    0.55   10     -5.25     0         0.08          0.09
# 39          0.57    0.65   10     -4.89     1         0.04          0.58
# 40          0.67    0.67   11     -6.94     0         0.04          0.15
# 41          0.83    0.80    9     -5.39     1         0.09          0.02
# 42          0.55    0.82    0     -4.21     1         0.05          0.12
# 43          0.75    0.76    7     -4.63     0         0.04          0.03
# 44          0.38    0.34    3     -7.88     1         0.03          0.69
# 45          0.71    0.73   10     -4.59     1         0.05          0.30
# 46          0.54    0.51   10     -6.05     1         0.03          0.73
# 47          0.64    0.70    4     -6.33     0         0.08          0.09
# 48          0.64    0.65    1     -4.60     1         0.12          0.28
# 49          0.80    0.68   11     -3.97     0         0.04          0.02
#
#     instrumentalness  liveness  valence  tempo                      id  \
# 0               0.00      0.31     0.66 173.93  4LRPiXqCikLlN15c3yImP7
# 1               0.00      0.09     0.53  80.87  02MWAaffLxlfxAUY7c5dvx
# 2               0.00      0.10     0.48 169.93  5HCyWlXZPP0y6Gqq8TgA20
# 3               0.00      0.09     0.42  92.00  6Sq7ltF9Qa7SNFBsV5Cogx
# 4               0.00      0.13     0.19 106.67  1IHWl5LamUGEuP4ozKQSXZ
# 5               0.00      0.10     0.94 116.03  6zSpb8dQRaw0M1dK8PBwQz
# 6               0.00      0.43     0.56  77.01  1r9xUipOqoNwggBpENDsvJ
# 7               0.03      0.23     0.55 128.03  2tTmW7RDtMQtBk7m2rYeSw
# 8               0.00      0.53     0.27  79.93  3k3NWokhRRkEPhCzPmV8TW
# 9               0.00      0.05     0.14 108.30  29d0nY7TzCoi22XBqDQkiP
# 10              0.00      0.05     0.89 150.00  27NovPIUIRrOZoCHxABJwK
# 11              0.00      0.37     0.41 121.93  4fouWK6XVHhzl78KzQ1UjL
# 12              0.00      0.06     0.23  98.05  5Eax0qFko2dh7Rl2lYs3bx
# 13              0.00      0.41     0.44 153.96  6I3mqTwhRpn34SLVafSH7G
# 14              0.00      0.14     0.27 169.91  6xGruZOHLs39ZbVccQTuPZ
# 15              0.00      0.12     0.29  99.97  6Xom58OOXk2SoU711L2IXO
# 16              0.00      0.04     0.82 141.02  50nfwKoDiSYg8zOCREWAm5
# 17              0.00      0.13     0.13 141.98  0gplL1WMoJ6iYaPgMCL0gX
# 18              0.00      0.12     0.09 185.73  58HvfVOeJY7lUuCqF0m3ly
# 19              0.00      0.12     0.88 108.00  6Uj1ctrBOjOas8xZXGqKk4
# 20              0.02      0.10     0.40 124.05  2QjOHCTQ1Jl3zawyYOpxh6
# 21              0.00      0.09     0.51  90.02  6mmPpaltUZK7xjNlBPQQ0p
# 22              0.00      0.09     0.13 122.77  3JvKfv6T31zO0ini8iNItO
# 23              0.01      0.11     0.53 111.00  7dSZ6zGTQx66c2GF91xCrb
# 24              0.00      0.33     0.96  95.00  0QBzMgT7NIeoCYy3sJCof1
# 25              0.00      0.11     0.33 107.00  0wHFktze2PHC5jDt3B17DC
# 26              0.00      0.09     0.33 171.00  0VjIjW4GlUZAMYd2vXMi3b
# 27              0.00      0.14     0.90  93.99  1ri9ZUkBJVFUdgwzCnfcYs
# 28              0.00      0.17     0.26 120.97  3uUuGVFu1V7jTQL60S1r8z
# 29              0.00      0.37     0.54 126.01  3rmo8F54jFF8OgYsqTxm5d
# 30              0.00      0.13     0.44 130.00  5fwSHlTEWpluwOM0Sxnh5k
# 31              0.00      0.08     0.69 166.93  4ZtFanR9U6ndgddUvNcjcG
# 32              0.00      0.09     0.45 116.96  2eAvDnpXP5W0cVtiI0PUxV
# 33              0.00      0.34     0.72 108.97  1PckUlxKqWQs3RlWXVBLw3
# 34              0.00      0.05     0.55  87.98  0e8nrvls4Qqv5Rfa2UhqmO
# 35              0.00      0.05     0.82 139.99  4h9wh7iOZ0GGn8QVp4RAOB
# 36              0.00      0.33     0.47 105.01  46HNZY1i7O6jwTA7Slo2PI
# 37              0.00      0.22     0.85 124.98  5ww2BF9slyYgNOk37BlC4u
# 38              0.00      0.05     0.83  96.02  1O2pcBJGej0pmH2Y9XZMs6
# 39              0.00      0.12     0.47  75.98  4SqWKzw0CbA05TGszDgMlc
# 40              0.00      0.30     0.49 121.96  1SOClUWhOi8vHZYMz3GluK
# 41              0.00      0.24     0.47  97.01  4tYFy8ALRjIZvnvSLw5lxN
# 42              0.00      0.34     0.56  95.39  6UelLqGlWMcVH1E5c4H7lY
# 43              0.00      0.09     0.46 117.95  18asYwWugKjjsihZ0YvRxO
# 44              0.00      0.12     0.08 100.61  5CZ40GBx1sQ9agT82CLQCT
# 45              0.00      0.11     0.90 115.00  1qEmFfgcLObUfQm0j1W2CK
# 46              0.00      0.17     0.23 101.36  0T5iIrXA4p5GsubkhuBIKV
# 47              0.00      0.09     0.14 169.89  4gzsuuZypVbxs0Af1LSZyB
# 48              0.00      0.14     0.44 179.95  2JPLbjOn0wPCngEot2STUS
# 49              0.00      0.66     0.42 114.01  41oY4WCTj5kccfesTVFnvN
#
#     duration_ms  time_signature
# 0        167303               4
# 1        238805               4
# 2        141806               4
# 3        178567               4
# 4        243717               4
# 5        202735               4
# 6        173381               4
# 7        198938               4
# 8        258299               4
# 9        300840               4
# 10       212000               4
# 11       168602               4
# 12       213061               4
# 13       153190               4
# 14       233456               3
# 15       245940               4
# 16       207853               4
# 17       224695               4
# 18       184448               3
# 19       172627               4
# 20       240400               4
# 21       224997               4
# 22       244360               4
# 23       210200               4
# 24       206071               4
# 25       173948               4
# 26       200040               4
# 27       226088               4
# 28       148197               4
# 29       230747               4
# 30       287120               4
# 31       178147               4
# 32       233720               3
# 33       191822               4
# 34       143901               4
# 35       148486               4
# 36       226198               4
# 37       162638               4
# 38       153750               4
# 39       160240               4
# 40       237720               4
# 41       227629               4
# 42       174000               4
# 43       164819               4
# 44       229227               4
# 45       177955               4
# 46       177720               3
# 47       207301               4
# 48       206710               4
# 49       237895               4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   position          50 non-null     int64
#  1   name              50 non-null     object
#  2   popularity        50 non-null     int64
#  3   danceability      50 non-null     float64
#  4   energy            50 non-null     float64
#  5   key               50 non-null     int64
#  6   loudness          50 non-null     float64
#  7   mode              50 non-null     int64
#  8   speechiness       50 non-null     float64
#  9   acousticness      50 non-null     float64
#  10  instrumentalness  50 non-null     float64
#  11  liveness          50 non-null     float64
#  12  valence           50 non-null     float64
#  13  tempo             50 non-null     float64
#  14  id                50 non-null     object
#  15  duration_ms       50 non-null     int64
#  16  time_signature    50 non-null     int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 6.8+ KB

# %%
df.describe()
# Out:
#        position  popularity  danceability  energy   key  loudness  mode  \
# count     50.00       50.00         50.00   50.00 50.00     50.00 50.00
# mean      25.50       83.40          0.69    0.67  5.38     -5.76  0.48
# std       14.58        3.75          0.13    0.13  3.70      1.81  0.50
# min        1.00       76.00          0.38    0.32  0.00    -11.90  0.00
# 25%       13.25       81.00          0.60    0.62  2.00     -6.37  0.00
# 50%       25.50       83.00          0.70    0.70  5.00     -5.52  0.00
# 75%       37.75       85.75          0.80    0.76  9.00     -4.60  1.00
# max       50.00       92.00          0.91    0.89 11.00     -2.72  1.00
#
#        speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# count        50.00         50.00             50.00     50.00    50.00  50.00
# mean          0.07          0.24              0.00      0.18     0.49 120.62
# std           0.05          0.24              0.01      0.14     0.25  29.32
# min           0.03          0.00              0.00      0.04     0.08  75.98
# 25%           0.04          0.04              0.00      0.09     0.30  98.53
# 50%           0.05          0.12              0.00      0.12     0.47 115.51
# 75%           0.08          0.34              0.00      0.24     0.64 137.50
# max           0.27          0.89              0.03      0.66     0.96 185.73
#
#        duration_ms  time_signature
# count        50.00           50.00
# mean     203046.18            3.92
# std       37317.13            0.27
# min      141806.00            3.00
# 25%      173522.75            4.00
# 50%      206390.50            4.00
# 75%      230367.00            4.00
# max      300840.00            4.00

# %%
df.corr()
# Out:
#                   position  popularity  danceability  energy   key  loudness  \
# position              1.00       -0.21         -0.03    0.03  0.17      0.21
# popularity           -0.21        1.00         -0.15    0.08 -0.17      0.09
# danceability         -0.03       -0.15          1.00    0.32  0.11      0.33
# energy                0.03        0.08          0.32    1.00 -0.15      0.67
# key                   0.17       -0.17          0.11   -0.15  1.00     -0.08
# loudness              0.21        0.09          0.33    0.67 -0.08      1.00
# mode                  0.07        0.12         -0.30   -0.09 -0.14      0.10
# speechiness          -0.16       -0.10          0.15    0.19  0.05      0.15
# acousticness          0.00        0.05         -0.33   -0.71  0.21     -0.50
# instrumentalness     -0.20        0.34         -0.05    0.14 -0.06      0.07
# liveness              0.05       -0.05         -0.00    0.17  0.23      0.16
# valence               0.03       -0.04          0.50    0.50  0.01      0.43
# tempo                -0.04        0.12         -0.45   -0.01 -0.23     -0.13
# duration_ms          -0.11       -0.17         -0.05   -0.21  0.17     -0.20
# time_signature       -0.06       -0.05          0.42    0.32 -0.03      0.14
#
#                   mode  speechiness  acousticness  instrumentalness  liveness  \
# position          0.07        -0.16          0.00             -0.20      0.05
# popularity        0.12        -0.10          0.05              0.34     -0.05
# danceability     -0.30         0.15         -0.33             -0.05     -0.00
# energy           -0.09         0.19         -0.71              0.14      0.17
# key              -0.14         0.05          0.21             -0.06      0.23
# loudness          0.10         0.15         -0.50              0.07      0.16
# mode              1.00        -0.25          0.19              0.21     -0.13
# speechiness      -0.25         1.00         -0.12             -0.11     -0.06
# acousticness      0.19        -0.12          1.00             -0.10     -0.16
# instrumentalness  0.21        -0.11         -0.10              1.00     -0.02
# liveness         -0.13        -0.06         -0.16             -0.02      1.00
# valence           0.09         0.02         -0.30              0.02      0.01
# tempo             0.21        -0.15         -0.03              0.02     -0.15
# duration_ms      -0.05        -0.18          0.09              0.07      0.05
# time_signature   -0.16         0.17         -0.22              0.08      0.11
#
#                   valence  tempo  duration_ms  time_signature
# position             0.03  -0.04        -0.11           -0.06
# popularity          -0.04   0.12        -0.17           -0.05
# danceability         0.50  -0.45        -0.05            0.42
# energy               0.50  -0.01        -0.21            0.32
# key                  0.01  -0.23         0.17           -0.03
# loudness             0.43  -0.13        -0.20            0.14
# mode                 0.09   0.21        -0.05           -0.16
# speechiness          0.02  -0.15        -0.18            0.17
# acousticness        -0.30  -0.03         0.09           -0.22
# instrumentalness     0.02   0.02         0.07            0.08
# liveness             0.01  -0.15         0.05            0.11
# valence              1.00  -0.10        -0.34            0.28
# tempo               -0.10   1.00        -0.13           -0.23
# duration_ms         -0.34  -0.13         1.00           -0.03
# time_signature       0.28  -0.23        -0.03            1.00

# %%
plt.figure(figsize=(18, 18))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1,
                      annot=True, fmt='.2f', annot_kws={"size": 13}, cmap='icefire')
heatmap.set_title('Corelations', fontdict={'fontsize': 20}, pad=20)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="loudness", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="danceability", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="acousticness", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="liveness", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
groupBy_key = df.groupby('key')
q_key = groupBy_key.size()
q_key
# Out:
# key
# 0      2
# 1     10
# 2      3
# 3      3
# 4      5
# 5      5
# 6      2
# 7      4
# 8      2
# 9      2
# 10     7
# 11     5
# dtype: int64

# %%
plt.figure(figsize=(20, 5))
ax = sns.barplot(x=q_key.index, y=q_key, color='#7099E6')
ax.set_title('Songs by Key')
ax.set_ylabel('N of Songs')
ax.set_xticklabels(['C', 'C#/Db', 'D', 'D#/Eb',
                   'E', 'F', 'F#/Gb', 'G', 'G#/Ab', 'A', 'A#/Bb', 'B'])
ax.margins(0.01)
plt.show()

# %%
groupBy_mode = df.groupby('mode')
q_mode = groupBy_mode.size()
q_mode
# Out:
# mode
# 0    26
# 1    24
# dtype: int64

# %%
plt.figure(figsize=(10, 5))
ax = sns.barplot(x=q_mode.index, y=q_mode, color='#7099E6')
ax.set_title('Valores por Bairros')
ax.set_ylabel('Valor')
ax.set_xticklabels(['Minor', 'Major'])
plt.show()
