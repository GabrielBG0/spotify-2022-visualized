# %%
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_columns', None)
sns.set_style("darkgrid")
sns.set_palette("colorblind")
sns.set_context("poster", font_scale=1, rc={
                "grid.linewidth": 5, "axes.linewidth": 5})

# %%
df = pd.read_csv('spotify_top_charts_22.csv')

df
# Out:
#                                       uri  \
# 0    spotify:track:02MWAaffLxlfxAUY7c5dvx
# 1    spotify:track:5PjdY0CKGZdEuoNab3yDmX
# 2    spotify:track:3IAfUEeaXRX9s9UdKOJrFI
# 3    spotify:track:1HhNoOuqm1a5MXYEgAFl8o
# 4    spotify:track:4fouWK6XVHhzl78KzQ1UjL
# ..                                    ...
# 641  spotify:track:0So2sgVa8aJiARPl2P29u2
# 642  spotify:track:1TUuhV75FeOF6UObRsABo2
# 643  spotify:track:3GbQcjKWT7eVpUfzqwUjxv
# 644  spotify:track:7My9ca9QEIR8MvIOdIrTWA
# 645  spotify:track:4axSuOg3BqsowKjRpj59RU
#
#                                         artist_names  \
# 0                                      Glass Animals
# 1                       The Kid LAROI, Justin Bieber
# 2                                             Anitta
# 3    Imagine Dragons, JID, Arcane, League of Legends
# 4                                              GAYLE
# ..                                               ...
# 641                                            SALES
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uri               646 non-null    object
#  1   artist_names      646 non-null    object
#  2   track_name        646 non-null    object
#  3   peak_rank         646 non-null    int64
#  4   weeks_on_chart    646 non-null    int64
#  5   danceability      646 non-null    float64
#  6   energy            646 non-null    float64
#  7   key               646 non-null    int64
#  8   loudness          646 non-null    float64
#  9   mode              646 non-null    int64
#  10  speechiness       646 non-null    float64
#  11  acousticness      646 non-null    float64
#  12  instrumentalness  646 non-null    float64
#  13  liveness          646 non-null    float64
#  14  tempo             646 non-null    float64
#  15  time_signature    646 non-null    int64
# ...

# %%
df.describe()
# Out:
#         peak_rank  weeks_on_chart  danceability      energy         key  \
# count  646.000000      646.000000    646.000000  646.000000  646.000000
# mean    65.922601       19.498452      0.674426    0.640836    5.086687
# std     57.004503       37.813937      0.151527    0.165478    3.622314
# min      1.000000        1.000000      0.193000    0.021800    0.000000
# 25%     15.000000        1.000000      0.569000    0.532500    1.000000
# 50%     51.500000        5.000000      0.700000    0.652000    5.000000
# 75%    108.750000       19.750000      0.790750    0.769000    8.000000
# max    200.000000      269.000000      0.985000    0.972000   11.000000
#
#          loudness        mode  speechiness  acousticness  instrumentalness  \
# count  646.000000  646.000000   646.000000    646.000000        646.000000
# mean    -6.356034    0.577399     0.109797      0.255699          0.013686
# std      2.627462    0.494356     0.102167      0.262595          0.077836
# ...

# %%
df.query('peak_rank == 1')
# Out:
#                                       uri  \
# 0    spotify:track:02MWAaffLxlfxAUY7c5dvx
# 1    spotify:track:5PjdY0CKGZdEuoNab3yDmX
# 4    spotify:track:4fouWK6XVHhzl78KzQ1UjL
# 11   spotify:track:46IZ0fSY2mpAiktS3KOqds
# 23   spotify:track:4ZtFanR9U6ndgddUvNcjcG
# 26   spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 46   spotify:track:1SC5rEoYDGUK4NfG82494W
# 54   spotify:track:5wANPM4fQCJwkGd4rN57mH
# 58   spotify:track:4MzXwWMhyBbmu6hOcLVD49
# 68   spotify:track:3Wrjm47oTz2sjIgck11l5e
# 87   spotify:track:4iJyoBOLtHqaGxP12qzhQI
# 93   spotify:track:0RiRZpuVRbi7oqRdSMwhQY
# 139  spotify:track:7qiZfU4dY1lWllzX7mPBI3
# 154  spotify:track:4jPy3l0RUwlUI9T5XHBW2m
# 157  spotify:track:5enxwA8aAbwZbf5qCHORXi
# 158  spotify:track:21jGcNKet2qwijlDFuPiPb
# 166  spotify:track:2N8m6CYs74qQO4mjVcXO30
# 182  spotify:track:35mvY5S1H3J2QZyna3TFe0
# 194  spotify:track:6v3KW9xbzN5yKLt9YKDYA2
# 200  spotify:track:2tTmW7RDtMQtBk7m2rYeSw
# 201  spotify:track:4Dvkj6JhhA12EX05fT7y2e
# ...

# %%
df.corr()
# Out:
# C:\Users\gabre\AppData\Local\Temp\ipykernel_7980\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   peak_rank  weeks_on_chart  danceability    energy       key  \
# peak_rank          1.000000       -0.352513     -0.011647  0.064726  0.032814
# weeks_on_chart    -0.352513        1.000000     -0.062471 -0.065588  0.017296
# danceability      -0.011647       -0.062471      1.000000  0.198659  0.048686
# energy             0.064726       -0.065588      0.198659  1.000000  0.032316
# key                0.032814        0.017296      0.048686  0.032316  1.000000
# loudness           0.030000        0.053077      0.251823  0.693982  0.014602
# mode              -0.024764        0.024224     -0.093857  0.002716 -0.133622
# ...

# %%
plt.figure(figsize=(18, 18))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1,
                      annot=True, fmt='.2f', annot_kws={"size": 13}, cmap='icefire')
heatmap.set_title('Correlações', fontdict={'fontsize': 20},pad=20)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="loudness", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="danceability", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="peak_rank", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="acousticness", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="liveness", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="key", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data=df, x="mode", kde=True)
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})

# %%
# 37i9dQZF1DX18jTM2l2fJY
